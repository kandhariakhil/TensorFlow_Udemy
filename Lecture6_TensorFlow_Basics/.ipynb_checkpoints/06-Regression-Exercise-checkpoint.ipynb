# %% [markdown]
# # Regression Exercise
#
# California Housing Data
#
# This data set contains information about all the block groups in California from the 1990 Census. In this sample a block group on average includes 1425.5 individuals living in a geographically compact area.
#
# The task is to aproximate the median house value of each block from the values of the rest of the variables.
#
#  It has been obtained from the LIACC repository. The original page where the data set can be found is: http://www.liaad.up.pt/~ltorgo/Regression/DataSets.html.

# %% [markdown]
# The Features:
#
# * housingMedianAge: continuous.
# * totalRooms: continuous.
# * totalBedrooms: continuous.
# * population: continuous.
# * households: continuous.
# * medianIncome: continuous.
# * medianHouseValue: continuous.

# %% [markdown]
# ## The Data

# %% [markdown]
# ** Import the cal_housing_clean.csv file with pandas. Separate it into a training (70%) and testing set(30%).**

# %%
import pandas as pd

# %%
cal_housing = pd.read_csv('cal_housing_clean.csv')

# %%
cal_housing.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0              41.0       880.0          129.0       322.0       126.0
# 1              21.0      7099.0         1106.0      2401.0      1138.0
# 2              52.0      1467.0          190.0       496.0       177.0
# 3              52.0      1274.0          235.0       558.0       219.0
# 4              52.0      1627.0          280.0       565.0       259.0
#
#    medianIncome  medianHouseValue
# 0        8.3252          452600.0
# 1        8.3014          358500.0
# 2        7.2574          352100.0
# 3        5.6431          341300.0
# 4        3.8462          342200.0

# %%
cal_housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_data = cal_housing.drop(labels='medianHouseValue',axis=1)

# %%
x_data.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0              41.0       880.0          129.0       322.0       126.0
# 1              21.0      7099.0         1106.0      2401.0      1138.0
# 2              52.0      1467.0          190.0       496.0       177.0
# 3              52.0      1274.0          235.0       558.0       219.0
# 4              52.0      1627.0          280.0       565.0       259.0
#
#    medianIncome
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462

# %%
y_label = cal_housing['medianHouseValue']

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_label, test_size=0.3, random_state=101)

# %% [markdown]
# ### Scale the Feature Data
#
# ** Use sklearn preprocessing to create a MinMaxScaler for the feature data. Fit this scaler only to the training data. Then use it to transform X_test and X_train. Then use the scaled X_test and X_train along with pd.Dataframe to re-create two dataframes of scaled data.**

# %%
cols_to_normalize = ['housingMedianAge','totalRooms','totalBedrooms','population','households','medianIncome','medianHouseValue']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = pd.DataFrame(data=scaler.transform(X_train),columns=X_train.columns,index=X_train.index)

# %%
X_test = pd.DataFrame(data=scaler.transform(X_test),columns=X_test.columns,index=X_test.index)

# %% [markdown]
# ### Create Feature Columns
#
# ** Create the necessary tf.feature_column objects for the estimator. They should all be trated as continuous numeric_columns. **

# %%
cal_housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
housingMedianAge = tf.feature_column.numeric_column('housingMedianAge')

# %%
totalRooms = tf.feature_column.numeric_column('totalRooms')
totalBedrooms = tf.feature_column.numeric_column('totalBedrooms')
population = tf.feature_column.numeric_column('population')
households = tf.feature_column.numeric_column('households')
income = tf.feature_column.numeric_column('medianIncome')

# %%
feat_cols = [housingMedianAge,totalRooms,totalBedrooms,population,households,income]

# %% [markdown]
# ** Create the input function for the estimator object. (play around with batch_size and num_epochs)**

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train,y_train,batch_size=128,num_epochs=1000,shuffle=True)

# %% [markdown]
# ** Create the estimator model. Use a DNNRegressor. Play around with the hidden units! **

# %%
model = tf.estimator.DNNRegressor(hidden_units=[10,10,10],feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpt4n8ptlk
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpt4n8ptlk', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fef4a78b5c0>, '_global_id_in_cluster': 0, '_evaluation_master': '', '_num_worker_replicas': 1, '_device_fn': None, '_save_checkpoints_secs': 600, '_service': None, '_keep_checkpoint_every_n_hours': 10000, '_experimental_distribute': None, '_save_summary_steps': 100, '_task_id': 0, '_experimental_max_worker_delay_secs': None, '_protocol': None, '_keep_checkpoint_max': 5, '_train_distribute': None, '_num_ps_replicas': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %% [markdown]
# ##### ** Train the model for ~1,000 steps. (Later come back to this and train it for more and check for improvement) **

# %%
model.train(input_fn=input_func,steps=100000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x7fef1460d6d8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x7fef1460d6d8>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %% [markdown]
# ** Create a prediction input function and then use the .predict method off your estimator model to create a list or predictions on your test data. **

# %%
import tensorflow as tf

# %%
predict_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
predict_gen = model.predict(predict_input_func)

# %% [markdown]
# ** Calculate the RMSE. You should be able to get around 100,000 RMSE (remember that this is in the same units as the label.) Do this manually or use [sklearn.metrics](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html) **

# %%
predictions = list(predict_gen)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x7fef490c1780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _DNNModel.call of <tensorflow_estimator.python.estimator.canned.dnn._DNNModel object at 0x7fef490c1780>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
predictions
# Out:
# [{'predictions': array([763819.5], dtype=float32)},
#  {'predictions': array([1206044.8], dtype=float32)},
#  {'predictions': array([610243.6], dtype=float32)},
#  {'predictions': array([557707.4], dtype=float32)},
#  {'predictions': array([966859.3], dtype=float32)},
#  {'predictions': array([438789.7], dtype=float32)},
#  {'predictions': array([620621.5], dtype=float32)},
#  {'predictions': array([579939.2], dtype=float32)},
#  {'predictions': array([681636.8], dtype=float32)},
#  {'predictions': array([747533.25], dtype=float32)},
#  {'predictions': array([531978.3], dtype=float32)},
#  {'predictions': array([438877.72], dtype=float32)},
#  {'predictions': array([541881.4], dtype=float32)},
#  {'predictions': array([532269.06], dtype=float32)},
#  {'predictions': array([788792.8], dtype=float32)},
#  {'predictions': array([574838.], dtype=float32)},
#  {'predictions': array([603724.4], dtype=float32)},
#  {'predictions': array([521902.7], dtype=float32)},
# ...

# %%
final_pred = []

for pred in predictions:
    final_pred.append(pred['predictions'])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,final_pred)**0.5
# Out:
# 388233.81469701754

# %% [markdown]
# # Great Job!
